# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

data_list = []
for i in range(10,460,10):
    data = np.loadtxt('/Users/sholafolarin/Desktop/DOT_FILES/parameter_plot/output_{}'.format(i))
    data_list.append(data)
    
new_data = np.zeros((45,6))

for j in range(45):
    new_data[j] = data_list[j]
    
df = 7.4713*(1+pd.DataFrame(new_data, columns=['S1','S2','S3','S4','S5','S6']))

temp_list = np.arange(10,460,10)

plt.plot(temp_list, df['S1'])
plt.plot(temp_list, df['S2'])
plt.plot(temp_list, df['S3'])
plt.plot(temp_list, df['S4'])
plt.plot(temp_list, df['S5'])
plt.plot(temp_list, df['S6'])
